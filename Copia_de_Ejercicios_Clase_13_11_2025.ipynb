# %% [markdown]
# <a href="https://colab.research.google.com/github/diegonz-FC/Entregas-en-Python/blob/main/Copia_de_Ejercicios_Clase_13_11_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1480. Running Sum of 1D Array
#
# Given an array nums. We define a running sum of an array as runningSum[i] = sum(nums[0]…nums[i]).
#
# Return the running sum of nums.

# %%
lista = input('Ingrese una cadena de números separados por comas ')
listint = [int(x.strip()) for x in lista.split(",")]
a = len(listint)
i=0
#sumat[0] = listint[0]
for i in range (1, a-1):
    sumat[i] += listint[i] + sumat[i-1]

print(sumat)
# Out:
# Ingrese una cadena de números separados por comas 1, 2, 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-175044666.py in <cell line: 0>()
#       5 #sumat[0] = listint[0]
#       6 for i in range (1, a-1):
# ----> 7     sumat[i] += listint[i] + sumat[i-1]
#       8
#       9 print(sumat)
#
# IndexError: list index out of range

# %%
class Solution:
    lista = input('Ingrese una cadena de números separados por comas ')
lists = lista.split(",")
listnt = [int(a) for a in lists]
a = listnt[0]
i=0
suma = [0] * len(listint) # Crea una lista de 0 de longitud la lista de listnt

suma[0] = a
for i in range (1, len(listnt)):
    suma[i] = listnt[i] + suma[i-1]
    i += 1

print(suma)
# Out:
# Ingrese una cadena de números separados por comas 1, 2, 3
# [1, 3, 6]

# %% [markdown]
# # 1342. Number of Steps to Reduce a Number to Zero
# Given an integer num, return the number of steps to reduce it to zero.
#
# In one step, if the current number is even, you have to divide it by 2, otherwise, you have to subtract 1 from it.

# %%
a = int(input('Ingrese un número entero mayor que 0 '))
i = 0

if a < 0:
    print('Error, ingrese un número entero mayor que 0')
else:

  while 0 < a <= 10000000:
    if a % 2 == 0:
      a = a / 2
      i += 1
    else:
      a = a-1
      i += 1
  print(i)
# Out:
# Ingrese un número entero mayor que 0 123
# 12

# %% [markdown]
# # 1672. Richest Customer Wealth
# You are given an m x n integer grid accounts where accounts[i][j] is the amount of money the i​​​​​​​​​​​th​​​​ customer has in the j​​​​​​​​​​​th​​​​ bank. Return the wealth that the richest customer has.
#
# A customer's wealth is the amount of money they have in all their bank accounts. The richest customer is the customer that has the maximum wealth.

# %%
A = input('Ingrese una cadena de números separados por comas ')
lstA = A.split(",")
intA = [int(a) for a in lstA]

B = input('Ingrese una cadena de números separados por comas ')
lstB = A.split(",")
intB = [int(a) for a in lstB]

suma1 = 0
for x in intA:
  suma1 = suma1 + x

suma2 = 0
for x in intB:
  suma1 = suma2 + x

if suma1 < suma2:
  print(suma1)
  else:
    print(suma2)
# Out:
# Ingrese una cadena de números separados por comas 1, 2, 3
# Ingrese una cadena de números separados por comas 2, 3, 4
# 0
